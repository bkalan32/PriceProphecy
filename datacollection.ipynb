# %%
from pathlib import Path
import pandas as pd

# %%
df1_path = ('resources/redfin_usa_data.csv')
df1 = pd.read_csv(df1_path)
df1
# Out:
#         price region  postal_code  baths  beds   sqft  lot_size  year_built
# 0    405000.0     NY      11354.0    1.0   2.0      -       NaN      1950.0
# 1    466995.0     OR      97756.0    2.0   4.0  1,979       NaN      2021.0
# 2   1175000.0     MO      63069.0    5.0   4.0  5,231      5.02      2005.0
# 3    484900.0     TN      37110.0    2.5   3.0  2,238      1.20      2018.0
# 4    317077.0     DE      19963.0    2.5   3.0  1,571      0.07      2021.0
# 5   1041250.0     MA       1519.0    2.5   4.0  4,421      0.32      2015.0
# 6    225900.0     AL      35016.0    2.0   3.0  1,561      2.50      1966.0
# 7    555821.0     GA      30107.0    2.5   4.0  2,753      0.27      2022.0
# 8    587659.0     CO      80104.0    2.0   4.0  1,740      0.18      2021.0
# 9    995000.0     AZ      85935.0    4.0   6.0  3,508      0.21      1997.0
# 10   145590.0     KY      41040.0    2.0   3.0  1,920      0.21      2004.0
# ...
